# %%
print("INSTRUCTIONS-\n")
print("Use commands 'go north', 'go south', 'go east', and 'go west' to get to the exit of the forest! Keep in mind there are many obstacles in the way such as logs, large trees, hedges, and more. The beast is chasing you, so try not to backtrack! If you get stuck and really need to, there might be something in your inventory that can help. To view your inventory press 'f'. To use something from it enter 'use __'. You only have 20 moves to escape the forest before the beast catches you, but some inventory items will slow the beast down and give you extra moves. Good luck!")
print("\n\n")
class Location:
    def __init__(self, name, message, items, npcs):
        self.name = name
        self.message = message
        self.items = items
        self.npc = npcs

l1 = Location('1', 'Forest', [], [])
l2 = Location('2', 'Forest', [], [])
l3 = Location('3', 'Forest', [], [])
l4 = Location('4', "You stumble upon a clearing that looks familiar... it's the exit of the forest!", [], [])
l5 = Location('5', 'Forest', [], [])
l6 = Location('6', 'Forest', [], [])
l7 = Location('7', 'Forest', [], [])
l8 = Location('8', 'Forest', [], [])
l9 = Location('9', 'Forest', [], [])
l10 = Location('10', 'Forest', [], [])
l11= Location('11', 'Forest', [], [])
l12 = Location('12', 'Forest', [], [])
l13 = Location('13', 'Forest', [], [])
l14 = Location('14', 'Forest', [], [])
l15 = Location('15', 'Forest', [], [])
l16 = Location('16', 'Forest', [], [])
l17 = Location('17', 'Forest', [], [])
l18 = Location('18', 'Forest', [], [])
l19 = Location('19', 'Forest', [], [])
l20 = Location('20', 'Forest', [], [])
l21 = Location('21', 'Forest', [], [])
l22 = Location('22', 'Forest', [], [])
l23 = Location('23', 'Forest', [], [])
l24 = Location('24', 'Forest', [], [])
l25 = Location('25', 'Forest', [], [])
l26 = Location('26', 'Forest', [], [])
l27 = Location('27', 'Forest', [], [])
l28 = Location('28', 'Forest', [], [])
l29 = Location('29', 'Forest', [], [])
l30 = Location('30', 'Forest', [], [])
l31 = Location('31', 'Forest', [], [])
l32 = Location('32', 'Forest', [], [])
l33 = Location('33', 'Forest', [], [])
l34 = Location('34', 'Forest', [], [])
l35 = Location('35', 'Forest', [], [])
l36 = Location('36', 'Forest', [], [])
l37 = Location('37', "You're back at the clearing you stole the healing tree from!", ['tree'], [])
l38 = Location('38', 'Forest', [], [])
l39 = Location('39', 'Forest', [], [])
l40 = Location('40', 'Forest', [], [])
l41 = Location('41', 'Forest', [], [])
l42 = Location('42', 'Forest', [], [])
l43 = Location('43', 'Forest', [], [])
l44 = Location('44', 'Forest', [], [])
l45 = Location('45', 'Forest', [], [])
l46 = Location('46', 'Forest', [], [])
l47 = Location('47', 'Forest', [], [])
l48 = Location('48', 'Forest', [], [])
l49 = Location('49', 'Forest', [], [])

def beast(inventory):
    saveinventory = inventory
    moves = 20
    print(moves, "moves left")
    moveslist = ['outta range']
    x = -2
    y = -2
    locations = {
        (-3,3) : l1, 
        #(-2,3) : l2, 
        (-1,3) : l3, 
        (0,3) : l4, 
        (1,3) : l5, 
        (2,3) : l6, 
        #(3,3) : l7, 
        (-3,2) : l8,
        (-2,2) : l9,
        (-1,2) : l10,
        (0,2) : l11,
        (1,2) : l12,
        (2,2) : l13,
        (3,2) : l14,
        #(-3,1) : l15,
        (-2,1) : l16,
        (-1,1) : l17,
        #(0,1) : l18,
        (1,1) : l19,
        #(2,1) : l20,
        (3,1) : l21,
        (-3,0) : l22,
        #(-2,0) : l23,
        (-1,0) : l24,
        (0,0) : l25,
        (1,0) : l26,
        (2,0) : l27,
        #(3,0) : l28,
        (-3,-1) : l29,
        (-2,-1) : l30,
        (-1,-1) : l31,
        (0,-1) : l32,
        (1,-1) : l33,
        #(2,-1) : l34,
        (3,-1) : l35,
        (-3,-2) : l36,
        (-2,-2) : l37,
        (-1,-2) : l38,
        #(0,-2) : l39,
        (1,-2) : l40,
        (2,-2) : l41,
        (3,-2) : l42,
        (-3,-3) : l43,
        (-2,-3) : l44,
        (-1,-3) : l45,
        (0,-3) : l46,
        (1,-3) : l47,
        #(2,-3) : l48,
        (3,-3) : l49,
        }
    
    max_coord_pos = 3
    max_coord_neg = -3

    print("Uh-oh. The beast isn't too happy about you taking the healing tree. I hope you remember the path you took to get here- run!!")
    command = input().lower()
    while command:
        illegal = False
        if command == 'go north':
            if y + 1 > max_coord_pos:
                illegal = True
                print("The forest grows too dense to get through that direction. Look for a clearing to exit.") 
            elif (x,y+1) not in locations:
                illegal = True
                print("There is a large tree blocking the way! Try going another direction.")
            elif moveslist[-1] == 'go south':
                illegal = True
                moveslist.append('go north')
                print("You just came from that direction! If you go back now the beast will get you. Try going another direction or using something from your inventory to distract it while you run by. ")
            else:
                y += 1
        elif command == 'go east':
            if x + 1 > max_coord_pos:
                illegal = True
                print("The forest grows too dense to get through that direction. Look for a clearing to exit.")
            elif (x+1,y) not in locations:
                illegal = True
                print("There is a fallen log blocking the way! Try going another direction.")
            elif moveslist[-1] == 'go west':
                illegal = True
                moveslist.append('go east')
                print("You just came from that direction! If you go back now the beast will get you. Try going another direction or using something from your inventory to distract it while you run by. ")
            else:
                x += 1
        elif command == 'go south':
            if y - 1 < max_coord_neg:
                illegal = True
                print("The forest grows too dense to get through that direction. Look for a clearing to exit.")
            elif (x,y-1) not in locations:
                illegal = True
                print("There is a giant hedge blocking the way! Try going another direction.")
            elif moveslist[-1] == 'go north':
                illegal = True
                moveslist.append('go south')
                print("You just came from that direction! If you go back now the beast will get you. Try going another direction or using something from your inventory to distract it while you run by. ")
            else:
                y -= 1
        elif command == 'go west':
            if x - 1 < max_coord_neg:
                illegal = True
                print("The forest grows too dense to get through that direction. Look for a clearing to exit.")
            elif (x-1,y) not in locations:
                illegal = True
                print("There is a boulder blocking the way! Try going another direction.")
            elif moveslist[-1] == 'go east':
                illegal = True
                moveslist.append('go west')
                print("You just came from that direction! If you go back now the beast will get you. Try going another direction or using something from your inventory to distract it while you run by. ")
            else:
                x -= 1
        elif command == 'use food':
            if 'food' not in inventory:
                illegal = True
                print("There's no food in your inventory!")
            else:
                inventory.remove('food')
                moves += 4
                print("You throw the food on the ground at the feet of the beast and it stops to eat- you've temporarily distracted it! You run past it in the direction you came from.")
                if moveslist[-1] == 'go north':
                    y+=1
                elif moveslist[-1] == 'go south':
                    y-=1
                elif moveslist[-1] == 'go east':
                    x+=1
                elif moveslist[-1] == 'go west':
                    x-=1
        elif command == 'use elven plants':
            if 'elven plants' not in inventory:
                illegal = True
                print("There are no elven plants in your inventory!")
            else:
                inventory.remove('elven plants')
                moves += 4
                print("You toss the magical plants behind you and they grow huge in an instant, blocking the path of the beast!")
                if moveslist[-1] == 'go north':
                    del locations[(x,y-1)]
                elif moveslist[-1] == 'go south':
                    del locations[(x,y+1)]
                elif moveslist[-1] == 'go east':
                    del locations[(x-1,y)]
                elif moveslist[-1] == 'go west':
                    del locations[(x+1,y)]
        elif command == 'f':
            illegal = True
            print("\nInventory:")
            for item in inventory:
                print(item.title())
            print()
            moves += 1

        if not illegal:
            print(locations[(x,y)].message)
            moveslist.append(command)
        
        moves-=1
        print("\n" + str(moves) + " moves left")
        
        if moves == 0:
            print("You're lost in the forest!")
            break
        elif locations[(x,y)].message == "You stumble upon a clearing that looks familiar... it's the exit of the forest!":
            print("You escaped from the beast.")
            break
        else:
            command = input().lower()

beast(['food', 'elven plants', 'healing tree'])
